# %% [markdown]
# # First Part
# ## The data is already separated with  commas

# %%
# import libraries 
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
# getting data from wikipedia page using Beautiful soup tool 
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
wikipedia_page= requests.get(url).text
soup = BeautifulSoup(wikipedia_page,'lxml')

# %%
# put the data into a dataframe
table = soup.find('table',{'class':'wikitable sortable'})
table_rows = table.find_all('tr')
data = []
for row in table_rows:
    data.append([t.text.strip() for t in row.find_all('td')])

df = pd.DataFrame(data, columns=['PostalCode', 'Borough', 'Neighbourhood'])
print(df.head(5))
# Out:
#   PostalCode       Borough     Neighbourhood
# 0       None          None              None
# 1        M1A  Not assigned
# 2        M2A  Not assigned
# 3        M3A    North York         Parkwoods
# 4        M4A    North York  Victoria Village

# %%
#eliminate not assigned rows as the one with number 0
df = df[~df['PostalCode'].isnull()]

# %%
#eliminate not assigned rows 
df.drop(df[df['Borough']=="Not assigned"].index,axis=0, inplace=True)

# %%
#joining neighbourhoods with same postal code
df= df.groupby('PostalCode').agg(lambda x: ','.join(x))

# %%
df.shape
# Out:
# (103, 2)

# %%
#Reset index
df = df.reset_index()

# %%
df.shape
# Out:
# (103, 3)

# %%
df.head()
# Out:
#   PostalCode      Borough                           Neighbourhood
# 0        M1B  Scarborough                          Malvern, Rouge
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %% [markdown]
# # Second Part

# %%
url2= 'http://cocl.us/Geospatial_data'
location=pd.read_csv(url2)
location.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
location.rename(columns={'Postal Code': 'PostalCode'}, inplace=True)

# %%
location.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %%
dfjoin=df.join(location.set_index('PostalCode'), on='PostalCode')
dfjoin.head(5)
# Out:
#   PostalCode      Borough                           Neighbourhood   Latitude  \
# 0        M1B  Scarborough                          Malvern, Rouge  43.806686
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
dfjoin.shape
# Out:
# (103, 5)

# %% [markdown]
# # Third Part

# %%
#import all the libraries we need
import json
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans

# %% [markdown]
# ## Geographical coordinates of Toronto

# %%
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="ca_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# ## Create a map of Toronto with neighborhoods superimposed on top

# %%
# !pip -q install folium
print('Environment installed')
# Out:
# Environment installed

# %%
import folium

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# %%
for lat, lng, label in zip(dfjoin['Latitude'], dfjoin['Longitude'], dfjoin['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Explore neighbourhoods in Toronto with a limit of 100 venues return by API

# %%
CLIENT_ID = 'JAWT00P4N3T3XS25V0QCJRYQMSEHHDMGVUCM0A5WZAI4T25X' 
CLIENT_SECRET = 'W4RZTHR5ZJW3WJ1HGZRWN5Y4MF4FQSENEUQJ4AKUJD5JKIZK' 
VERSION = '20180605' 
LIMIT=100

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]["groups"][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=dfjoin['Neighbourhood'],latitudes=dfjoin['Latitude'],longitudes=dfjoin['Longitude'])

# %%
toronto_venues
# Out:
#                                           Neighbourhood  \
# 0                                        Malvern, Rouge
# 1                Rouge Hill, Port Union, Highland Creek
# 2                Rouge Hill, Port Union, Highland Creek
# 3                Rouge Hill, Port Union, Highland Creek
# 4                     Guildwood, Morningside, West Hill
# 5                     Guildwood, Morningside, West Hill
# 6                     Guildwood, Morningside, West Hill
# 7                     Guildwood, Morningside, West Hill
# 8                     Guildwood, Morningside, West Hill
# 9                     Guildwood, Morningside, West Hill
# 10                    Guildwood, Morningside, West Hill
# 11                                               Woburn
# 12                                               Woburn
# 13                                               Woburn
# 14                                               Woburn
# 15                                            Cedarbrae
# 16                                            Cedarbrae
# 17                                            Cedarbrae
# 18                                            Cedarbrae
# 19                                            Cedarbrae
# 20                                            Cedarbrae
# 21                                            Cedarbrae
# 22                                            Cedarbrae
# 23                                  Scarborough Village
# 24                                  Scarborough Village
# 25          Kennedy Park, Ionview, East Birchmount Park
# 26          Kennedy Park, Ionview, East Birchmount Park
# 27          Kennedy Park, Ionview, East Birchmount Park
# 28          Kennedy Park, Ionview, East Birchmount Park
# 29          Kennedy Park, Ionview, East Birchmount Park
# ...                                                 ...
# 2118                                             Weston
# 2119                                             Weston
# 2120                                          Westmount
# 2121                                          Westmount
# 2122                                          Westmount
# 2123                                          Westmount
# 2124                                          Westmount
# 2125                                          Westmount
# 2126                                          Westmount
# 2127                                          Westmount
# 2128  Kingsview Village, St. Phillips, Martin Grove ...
# 2129  Kingsview Village, St. Phillips, Martin Grove ...
# 2130  Kingsview Village, St. Phillips, Martin Grove ...
# 2131  Kingsview Village, St. Phillips, Martin Grove ...
# 2132  South Steeles, Silverstone, Humbergate, Jamest...
# 2133  South Steeles, Silverstone, Humbergate, Jamest...
# 2134  South Steeles, Silverstone, Humbergate, Jamest...
# 2135  South Steeles, Silverstone, Humbergate, Jamest...
# 2136  South Steeles, Silverstone, Humbergate, Jamest...
# 2137  South Steeles, Silverstone, Humbergate, Jamest...
# 2138  South Steeles, Silverstone, Humbergate, Jamest...
# 2139  South Steeles, Silverstone, Humbergate, Jamest...
# 2121                Pizza Place
# 2122                Coffee Shop
# 2123             Sandwich Place
# 2124                Pizza Place
# 2125  Middle Eastern Restaurant
# 2126               Intersection
# 2127             Discount Store
# 2128             Sandwich Place
# 2129                   Bus Line
# 2130                Pizza Place
# 2131          Mobile Phone Shop
# 2132             Sandwich Place
# 2133                   Pharmacy
# 2134        Fried Chicken Joint
# 2135              Grocery Store
# 2136                 Beer Store
# 2137              Grocery Store
# 2138                Pizza Place
# 2139       Fast Food Restaurant
# 2140                Coffee Shop
# 2141                Pizza Place
# 2142             Discount Store
# 2143        Japanese Restaurant
# 2144               Liquor Store
# 2145        Rental Car Location
# 2146                        Bar
# 2147                  Drugstore
#
# [2148 rows x 7 columns]

# %%
print('The number of rows & colums is', toronto_venues.shape)
toronto_venues.groupby('Neighbourhood').count()
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# The number of rows & colums is (2148, 7)
# There are 266 uniques categories.

# %% [markdown]
# ## Analyze each neighbourhood

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighbourhood'] = toronto_venues['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()
toronto_grouped
# Out:
#                                         Neighbourhood  Accessories Store  \
# 0                                           Agincourt           0.000000
# 1                              Alderwood, Long Branch           0.000000
# 2     Bathurst Manor, Wilson Heights, Downsview North           0.000000
# 3                                     Bayview Village           0.000000
# 4                   Bedford Park, Lawrence Manor East           0.000000
# 5                                         Berczy Park           0.000000
# 6                         Birch Cliff, Cliffside West           0.000000
# 7        Brockton, Parkdale Village, Exhibition Place           0.000000
# 8               Business reply mail Processing Centre           0.000000
# 9   CN Tower, King and Spadina, Railway Lands, Har...           0.000000
# 10                                Caledonia-Fairbanks           0.000000
# 11              Canada Post Gateway Processing Centre           0.000000
# 12                                          Cedarbrae           0.000000
# 13                                 Central Bay Street           0.000000
# 14                                           Christie           0.000000
# 15                               Church and Wellesley           0.000000
# 16            Clarks Corners, Tam O'Shanter, Sullivan           0.000000
# 17    Cliffside, Cliffcrest, Scarborough Village West           0.000000
# 18                     Commerce Court, Victoria Hotel           0.000000
# 19                                         Davisville           0.000000
# 20                                   Davisville North           0.000000
# 21   Del Ray, Mount Dennis, Keelsdale and Silverthorn           0.000000
# 22                                          Don Mills           0.000000
# 23  Dorset Park, Wexford Heights, Scarborough Town...           0.000000
# 24                                          Downsview           0.000000
# 25                       Dufferin, Dovercourt Village           0.000000
# 26                                       East Toronto           0.000000
# 27  Eringate, Bloordale Gardens, Old Burnhamthorpe...           0.000000
# 28                       Fairview, Henry Farm, Oriole           0.028986
# 29             First Canadian Place, Underground city           0.000000
# ..                                                ...                ...
# 65                                           Rosedale           0.000000
# 66                                           Roselawn           0.000000
# 67             Rouge Hill, Port Union, Highland Creek           0.000000
# 68                                 Runnymede, Swansea           0.000000
# 69                      Runnymede, The Junction North           0.000000
# 3           0.0       0.000000     0.000000
# 4           0.0       0.000000     0.000000
# 5           0.0       0.000000     0.000000
# 6           0.0       0.000000     0.000000
# 7           0.0       0.000000     0.043478
# 8           0.0       0.000000     0.062500
# 9           0.0       0.000000     0.000000
# 10          0.0       0.333333     0.000000
# 11          0.0       0.000000     0.000000
# 12          0.0       0.000000     0.000000
# 13          0.0       0.000000     0.015625
# 14          0.0       0.000000     0.000000
# 15          0.0       0.000000     0.025641
# 16          0.0       0.000000     0.000000
# 17          0.0       0.000000     0.000000
# 18          0.0       0.000000     0.000000
# 19          0.0       0.000000     0.000000
# 20          0.0       0.000000     0.000000
# 21          0.0       0.000000     0.000000
# 22          0.0       0.000000     0.000000
# 23          0.0       0.000000     0.000000
# 24          0.0       0.000000     0.000000
# 25          0.0       0.000000     0.000000
# 26          0.0       0.000000     0.000000
# 27          0.0       0.000000     0.000000
# 28          0.0       0.014493     0.000000
# 29          0.0       0.000000     0.000000
# ..          ...            ...          ...
# 65          0.0       0.000000     0.000000
# 66          0.0       0.000000     0.000000
# 67          0.0       0.000000     0.000000
# 68          0.0       0.000000     0.025000
# 69          0.0       0.000000     0.000000
# 70          0.0       0.000000     0.000000
# 71          0.0       0.000000     0.000000
# 72          0.0       0.000000     0.000000
# 73          0.0       0.000000     0.000000
# 74          0.0       0.000000     0.000000
# 75          0.0       0.000000     0.010526
# 76          0.0       0.000000     0.024390
# 77          0.0       0.000000     0.000000
# 78          0.0       0.000000     0.000000
# 79          0.0       0.000000     0.000000
# 80          0.0       0.000000     0.023810
# 81          0.0       0.000000     0.000000
# 82          0.0       0.000000     0.055556
# 83          0.0       0.000000     0.000000
# 84          0.0       0.000000     0.029412
# 85          0.0       0.000000     0.000000
# 86          0.0       0.000000     0.000000
# 87          0.0       0.000000     0.000000
# 88          0.0       0.000000     0.000000
# 89          0.0       0.000000     0.000000
# 90          0.0       0.000000     0.000000
# 91          0.0       0.000000     0.000000
# 92          0.0       0.000000     0.000000
# 93          0.0       0.000000     0.000000
# 94          0.0       0.000000     0.000000
#
# [95 rows x 267 columns]

# %% [markdown]
# ## print each neighborhood along with the top 5 most common venues

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues=10
indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                                         Neighbourhood 1st Most Common Venue  \
# 0                                           Agincourt                Lounge
# 1                              Alderwood, Long Branch           Pizza Place
# 2     Bathurst Manor, Wilson Heights, Downsview North           Coffee Shop
# 3                                     Bayview Village                  Café
# 4                   Bedford Park, Lawrence Manor East           Coffee Shop
# 5                                         Berczy Park           Coffee Shop
# 6                         Birch Cliff, Cliffside West       College Stadium
# 7        Brockton, Parkdale Village, Exhibition Place                  Café
# 8               Business reply mail Processing Centre           Yoga Studio
# 9   CN Tower, King and Spadina, Railway Lands, Har...        Airport Lounge
# 10                                Caledonia-Fairbanks                  Park
# 11              Canada Post Gateway Processing Centre           Coffee Shop
# 12                                          Cedarbrae   Fried Chicken Joint
# 13                                 Central Bay Street           Coffee Shop
# 14                                           Christie         Grocery Store
# 15                               Church and Wellesley           Coffee Shop
# 24                       Park                Snack Place
# 25                   Pharmacy                        Gym
# 26          Convenience Store           Department Store
# 27                Pizza Place                 Beer Store
# 28                Coffee Shop       Fast Food Restaurant
# 29                       Café                        Gym
# ..                        ...                        ...
# 65                      Trail                 Playground
# 66                     Garden               Home Service
# 67              Moving Target                        Bar
# 68                       Café                   Tea Room
# 69                   Bus Line       Caribbean Restaurant
# 70                 Playground                Yoga Studio
# 71                Pizza Place                 Beer Store
# 72                       Café                  Gastropub
# 73                 Restaurant         Italian Restaurant
# 74         Chinese Restaurant                        Gym
# 75                       Café                 Restaurant
# 76                Coffee Shop                  Gastropub
# 77                        Pub                 Bagel Shop
# 78             Sandwich Place                Coffee Shop
# 79               Neighborhood                Coffee Shop
# 80         Italian Restaurant                Coffee Shop
# 81                      River                Yoga Studio
# 82                Yoga Studio                Supermarket
# 83                       Café                      Hotel
# 84                  Bookstore                        Bar
# 85               Intersection                Coffee Shop
# 86                Yoga Studio              Deli / Bodega
# 87         Chinese Restaurant  Middle Eastern Restaurant
# 88          Convenience Store           Department Store
# 89             Breakfast Spot                     Bakery
# 90                Coffee Shop                Pizza Place
# 91          Indian Restaurant          Korean Restaurant
# 92                   Pharmacy                 Beer Store
# 93                        Bar                       Bank
# 94               Dance Studio       Ethiopian Restaurant
#
#     4th Most Common Venue        5th Most Common Venue  \
# 0          Clothing Store               Breakfast Spot
# 1          Sandwich Place           Athletics & Sports
# 2                Pharmacy             Sushi Restaurant
# 3     Japanese Restaurant                  Yoga Studio
# 4      Italian Restaurant             Sushi Restaurant
# 5      Seafood Restaurant                   Restaurant
# 6   General Entertainment                  Yoga Studio
# 7             Yoga Studio                Grocery Store
# 8                    Park                  Pizza Place
# 9        Sculpture Garden                     Boutique
# 10                Airport           Falafel Restaurant
# 11    American Restaurant     Mediterranean Restaurant
# 12       Hakka Restaurant                         Bank
# 13         Sandwich Place                 Dessert Shop
# 14             Baby Store                  Coffee Shop
# 15             Restaurant                          Pub
# 16        Thai Restaurant                 Intersection
# 17          Deli / Bodega                 Dessert Shop
# 18                  Hotel                          Gym
# 19            Coffee Shop           Italian Restaurant
# 20      Food & Drink Shop             Department Store
# 21         Sandwich Place             Department Store
# 22             Restaurant                   Beer Store
# 23  Vietnamese Restaurant       Thrift / Vintage Store
# 24             Food Truck               Baseball Field
# 25            Music Venue                         Park
# 26           Dessert Shop           Dim Sum Restaurant
# 27         Cosmetics Shop            Convenience Store
# 28      Accessories Store                   Restaurant
# 29                  Hotel                   Restaurant
# ..                    ...                          ...
# 65           Dance Studio                Deli / Bodega
# 66         Discount Store                Deli / Bodega
# 67            Yoga Studio               Discount Store
# 68                    Pub                    Bookstore
# 69      Convenience Store                      Dog Run
# 70    Distribution Center             Department Store
# 71         Sandwich Place                 Liquor Store
# 72           Cocktail Bar          American Restaurant
# 73                 Market                       Bakery
# 74            Supermarket                Grocery Store
# 75     Italian Restaurant          Japanese Restaurant
# 76                Brewery          American Restaurant
# 77    Fried Chicken Joint           Light Rail Station
# 78               Pharmacy                          Pub
# 79                    Pub            Health Food Store
# 80              Bookstore       Furniture / Home Store
# 81         Discount Store                Deli / Bodega
# 82                   Bank                 Burger Joint
# 83             Restaurant          Japanese Restaurant
# 84     Italian Restaurant          Japanese Restaurant
# 85            Pizza Place        Portuguese Restaurant
# 86   Ethiopian Restaurant            Electronics Store
# 87            Coffee Shop                 Intersection
# 88           Dessert Shop           Dim Sum Restaurant
# 89  Vietnamese Restaurant               Sandwich Place
# 90                   Café                Grocery Store
# 91                Dog Run                 Dessert Shop
# 92                    Spa                 Dance Studio
# 93      Convenience Store  Eastern European Restaurant
# 94      Electronics Store  Eastern European Restaurant
#
#           6th Most Common Venue      7th Most Common Venue  \
# 0                       Dog Run         Dim Sum Restaurant
# 1                          Pool                        Pub
# 2     Middle Eastern Restaurant              Shopping Mall
# 3              Department Store         Dim Sum Restaurant
# 4       Comfort Food Restaurant                   Pharmacy
# 5                          Café                     Bakery
# 6           Distribution Center               Dessert Shop
# 7                     Pet Store      Performing Arts Venue
# 8                       Butcher                 Restaurant
# 9           Rental Car Location                      Plane
# 10         Ethiopian Restaurant          Electronics Store
# 11               Sandwich Place              Burrito Place
# 12           Athletics & Sports       Caribbean Restaurant
# 13          Japanese Restaurant            Bubble Tea Shop
# 14                   Restaurant                      Diner
# 15                  Men's Store   Mediterranean Restaurant
# 16                 Noodle House                Coffee Shop
# 17           Dim Sum Restaurant                      Diner
# 18          American Restaurant         Seafood Restaurant
# 19                         Café           Sushi Restaurant
# 20               Sandwich Place                       Park
# 21                 Dessert Shop         Dim Sum Restaurant
# 22          Sporting Goods Shop                Coffee Shop
# 23                  Yoga Studio           Department Store
# 24                 Home Service         Athletics & Sports
# 25                         Pool  Middle Eastern Restaurant
# 26                        Diner             Discount Store
# 27                         Café                Coffee Shop
# 28                    Juice Bar                     Bakery
# 29          Japanese Restaurant                Salad Place
# ..                          ...                        ...
# 65             Department Store               Dessert Shop
# 66             Department Store               Dessert Shop
# 67             Department Store               Dessert Shop
# 68             Sushi Restaurant                Coffee Shop
# 69           Dim Sum Restaurant                      Diner
# 70                 Dessert Shop         Dim Sum Restaurant
# 71                  Coffee Shop        Fried Chicken Joint
# 72                  Art Gallery         Italian Restaurant
# 73                          Pub                Pizza Place
# 74                 Noodle House                   Pharmacy
# 75                     Beer Bar               Cocktail Bar
# 76                       Bakery             Clothing Store
# 77             Sushi Restaurant      Vietnamese Restaurant
# 78    Middle Eastern Restaurant                  BBQ Joint
# 79                Deli / Bodega           Department Store
# 80               Ice Cream Shop       Caribbean Restaurant
# 81             Department Store               Dessert Shop
# 82                  Coffee Shop             Discount Store
# 83                  Salad Place        American Restaurant
# 84                   Restaurant                     Bakery
# 85                 Hockey Arena                      Diner
# 86  Eastern European Restaurant                  Drugstore
# 87               Sandwich Place             Discount Store
# 88                        Diner             Discount Store
# 89                Shopping Mall  Middle Eastern Restaurant
# 90                   Restaurant             Sandwich Place
# 91           Dim Sum Restaurant                      Diner
# 92                  Curling Ice             Cosmetics Shop
# 93                    Drugstore                 Donut Shop
# 94                    Drugstore                 Donut Shop
#
#           8th Most Common Venue      9th Most Common Venue  \
# 0                         Diner             Discount Store
# 1                  Skating Rink                Coffee Shop
# 2                 Deli / Bodega                 Restaurant
# 3                         Diner             Discount Store
# 4                   Pizza Place                       Café
# 5                   Cheese Shop                       Park
# 6            Dim Sum Restaurant                      Diner
# 7                     Nightclub         Italian Restaurant
# 8                 Burrito Place                    Brewery
# 9                 Boat or Ferry            Harbor / Marina
# 10  Eastern European Restaurant                  Drugstore
# 11                 Intersection  Middle Eastern Restaurant
# 12              Thai Restaurant               Dessert Shop
# 13                 Burger Joint                        Bar
# 14           Athletics & Sports         Italian Restaurant
# 15                        Hotel                    Gay Bar
# 16           Italian Restaurant                Gas Station
# 17               Discount Store        Distribution Center
# 18           Italian Restaurant        Japanese Restaurant
# 19                  Pizza Place                   Pharmacy
# 20              Airport Service         Airport Food Court
# 21                        Diner             Discount Store
# 22         Caribbean Restaurant             Clothing Store
# 23                 Dessert Shop         Dim Sum Restaurant
# 24               Discount Store                 Playground
# 25                         Café               Liquor Store
# 26          Distribution Center                Yoga Studio
# 27                 Liquor Store               Concert Hall
# 28                     Tea Room                       Bank
# 29                   Steakhouse           Asian Restaurant
# ..                          ...                        ...
# 65           Dim Sum Restaurant                      Diner
# 66           Dim Sum Restaurant                      Diner
# 67           Dim Sum Restaurant                      Diner
# 68           Italian Restaurant                Yoga Studio
# 69               Discount Store        Distribution Center
# 70                        Diner             Discount Store
# 71                     Pharmacy       Fast Food Restaurant
# 72               Lingerie Store           Department Store
# 73                         Café                       Park
# 74                  Pizza Place             Sandwich Place
# 75           Seafood Restaurant                        Gym
# 76            Convenience Store                        Bar
# 77                 Liquor Store                       Bank
# 78                   Donut Shop             History Museum
# 79                 Dessert Shop         Dim Sum Restaurant
# 80                 Dessert Shop                       Café
# 81           Dim Sum Restaurant                      Diner
# 82         Fast Food Restaurant                Gas Station
# 83           Italian Restaurant         Seafood Restaurant
# 84           Chinese Restaurant               Dessert Shop
# 85                Deli / Bodega           Department Store
# 86                   Donut Shop           Doner Restaurant
# 87                  Yoga Studio               Dessert Shop
# 88          Distribution Center                Yoga Studio
# 89                    Drugstore                 Donut Shop
# 90              Bubble Tea Shop       Fast Food Restaurant
# 91               Discount Store        Distribution Center
# 92                 Skating Rink                Video Store
# 93             Doner Restaurant                    Dog Run
# 94             Doner Restaurant                    Dog Run
#
#        10th Most Common Venue
# 0         Distribution Center
# 1                 Curling Ice
# 2         Fried Chicken Joint
# 3         Distribution Center
# 4                         Pub
# 5                Concert Hall
# 6              Discount Store
# 7                Intersection
# 8                  Skate Park
# 9                         Bar
# 10                 Donut Shop
# 11        Fried Chicken Joint
# 12         Dim Sum Restaurant
# 13            Thai Restaurant
# 14                Candy Store
# 15                  Gastropub
# 16                       Bank
# 17                Yoga Studio
# 18              Deli / Bodega
# 19                      Diner
# 20                Event Space
# 21        Distribution Center
# 22              Shopping Mall
# 23                      Diner
# 24                       Bank
# 25                    Brewery
# 26              Deli / Bodega
# 27               Dessert Shop
# 28        Japanese Restaurant
# 29        American Restaurant
# ..                        ...
# 65             Discount Store
# 66                Yoga Studio
# 67        Distribution Center
# 68  Latin American Restaurant
# 69           Doner Restaurant
# 70                    Dog Run
# 71             Discount Store
# 72                   Creperie
# 73                  Pet Store
# 74            Bubble Tea Shop
# 75                        Pub
# 76           Stationery Store
# 77        American Restaurant
# 78             Cosmetics Shop
# 79                      Diner
# 80                        Pub
# 81        Distribution Center
# 82              Grocery Store
# 83        Sporting Goods Shop
# 84           Sushi Restaurant
# 85               Dessert Shop
# 86                    Dog Run
# 87         Dim Sum Restaurant
# 88              Deli / Bodega
# 89           Doner Restaurant
# 90                      Hotel
# 91                Yoga Studio
# 92    Comfort Food Restaurant
# 93              Deli / Bodega
# 94        Distribution Center
#
# [95 rows x 11 columns]

# %% [markdown]
# ## Cluster the neighborhoods ( 7 clusters, 10 top venues)

# %%
# set number of clusters
kclusters = 7

toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 5, 1, 1, 1, 1, 1, 1, 5, 1], dtype=int32)

# %% [markdown]
# ## Visualize the cluster

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
neighborhoods_venues_sorted.dtypes
# Out:
# Cluster Labels             int32
# Neighbourhood             object
# 1st Most Common Venue     object
# 2nd Most Common Venue     object
# 3rd Most Common Venue     object
# 4th Most Common Venue     object
# 5th Most Common Venue     object
# 6th Most Common Venue     object
# 7th Most Common Venue     object
# 8th Most Common Venue     object
# 9th Most Common Venue     object
# 10th Most Common Venue    object
# dtype: object

# %%
dfjoin.shape
# Out:
# (103, 5)

# %%
#eliminate row with NaN values
dfjoin=dfjoin.dropna()

# %%
neighborhoods_venues_sorted.shape
# Out:
# (95, 12)

# %%
neighborhoods_venues_sorted=neighborhoods_venues_sorted.dropna()

# %%
neighborhoods_venues_sorted.shape
# Out:
# (95, 12)

# %%
dfjoin=dfjoin.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')
dfjoin=dfjoin.dropna()

# %%
dfjoin.dtypes
# Out:
# PostalCode                 object
# Borough                    object
# Neighbourhood              object
# Latitude                  float64
# Longitude                 float64
# Cluster Labels            float64
# 1st Most Common Venue      object
# 2nd Most Common Venue      object
# 3rd Most Common Venue      object
# 4th Most Common Venue      object
# 5th Most Common Venue      object
# 6th Most Common Venue      object
# 7th Most Common Venue      object
# 8th Most Common Venue      object
# 9th Most Common Venue      object
# 10th Most Common Venue     object
# dtype: object

# %%
# change the type from float to inter
dfjoin=dfjoin.astype({"Cluster Labels": int})

# %%
dfjoin.dtypes
# Out:
# PostalCode                 object
# Borough                    object
# Neighbourhood              object
# Latitude                  float64
# Longitude                 float64
# Cluster Labels              int64
# 1st Most Common Venue      object
# 2nd Most Common Venue      object
# 3rd Most Common Venue      object
# 4th Most Common Venue      object
# 5th Most Common Venue      object
# 6th Most Common Venue      object
# 7th Most Common Venue      object
# 8th Most Common Venue      object
# 9th Most Common Venue      object
# 10th Most Common Venue     object
# dtype: object

# %%
# create map
import matplotlib.colors as colors
map_clusters = folium.Map(location = [latitude, longitude], zoom_start = 11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i * x) ** 2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(dfjoin['Latitude'], dfjoin['Longitude'], dfjoin['Neighbourhood'], dfjoin['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius = 5,
        popup = label,
        color = rainbow[cluster -1 ],
        fill = True,
        fill_color = rainbow[cluster - 1],
        fill_opacity = 0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
